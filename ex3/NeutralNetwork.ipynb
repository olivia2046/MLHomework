# %% [markdown]
# # Exercise 3 神经网络

# %%
## Machine Learning Online Class - Exercise 3 | Part 2: Neural Networks

#  Instructions
#  ------------
# 
#  This file contains code that helps you get started on the
#  linear exercise. You will need to complete the following functions 
#  in this exericse:
#
#     lrCostFunction.m (logistic regression cost function)
#     oneVsAll.m
#     predictOneVsAll.m
#     predict.m
#
#  For this exercise, you will not need to change any code in this file,
#  or any other files other than those mentioned above.
#

import numpy as np
import scipy.io as scio # to read the .mat file
import matplotlib.pyplot as plt
# %matplotlib inline
#import library as lib
import sys
sys.path.append('..')
import lib.plotting as libplt
import lib.predict as predict
## Setup the parameters you will use for this exercise
input_layer_size  = 400;  # 20x20 Input Images of Digits
hidden_layer_size = 25;   # 25 hidden units
num_labels = 10;          # 10 labels, from 1 to 10   
                          # (note that we have mapped "0" to label 10)

# %% [markdown]
# # 加载和展示数据

# %%
## =========== Part 1: Loading and Visualizing Data =============
#  We start the exercise by first loading and visualizing the dataset. 
#  You will be working with a dataset that contains handwritten digits.
#

# Load Training Data
print('Loading and Visualizing Data ...\n')

data = scio.loadmat('ex3data1.mat');
X = data['X']
y = data['y']
m = len(X)

# Randomly select 100 data points to display
sel = np.random.permutation(range(m));
sel = sel[:100];

libplt.displayData(X[sel, :])
plt.show()
# Out:
# Loading and Visualizing Data ...
#
# m, n: 100, 400

# %% [markdown]
# # 加载参数

# %%
## ================ Part 2: Loading Pameters ================
# In this part of the exercise, we load some pre-initialized 
# neural network parameters.

print('\nLoading Saved Neural Network Parameters ...\n')

# Load the weights into variables Theta1 and Theta2
param = scio.loadmat('ex3weights.mat');
Theta1 = param['Theta1']
Theta2 = param['Theta2']
# Out:
# Loading Saved Neural Network Parameters ...

# %%
Theta1.shape
# Out:
# (25, 401)

# %%
Theta2.shape
# Out:
# (10, 26)

# %%
X.shape
# Out:
# (5000, 400)

# %% [markdown]
# # 预测

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
import importlib
importlib.reload(predict)
# Out:
# <module 'lib.predict' from '..\\lib\\predict.py'>

# %%
## ================= Part 3: Implement Predict =================
#  After training the neural network, we would like to use it to predict
#  the labels. You will now implement the "predict" function to use the
#  neural network to predict the labels of the training set. This lets
#  you compute the training set accuracy.

pred = predict.predict(Theta1, Theta2, X);

#print('\nTraining Set Accuracy: %f\n'%np.mean((np.double(pred == y)) * 100));
#compare = np.column_stack((pred,y))
print('\nTraining Set Accuracy: %f\n'%( np.mean(np.double(pred.reshape(-1,1) == y))* 100));


#  To give you an idea of the network's output, you can also run
#  through the examples one at the a time to see what it is predicting.

#  Randomly permute examples

rp = np.random.permutation(range(m));

#for i in range(m):
for i in range(100):
    # Display 
    print('\nDisplaying Example Image %d\n'%i);
    X_pred = X[rp[i], :].reshape(1,X.shape[1])
    libplt.plot_an_image(X_pred) #X[rp[i], :].shape； (400,1)
    #plt.show()
    
    
    pred = predict.predict(Theta1, Theta2, X_pred)
    print('\nNeural Network Prediction: %d (digit %d)\n'%(pred, np.mod(pred, 10)));
# Out:
# Training Set Accuracy: 97.520000
#
#
# Displaying Example Image 0
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 1
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 2
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 3
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 4
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 5
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 6
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 7
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 8
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 9
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 10
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 11
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 12
# Neural Network Prediction: 7 (digit 7)
#
#
# Displaying Example Image 13
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 14
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 15
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 16
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 17
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 18
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 19
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 20
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 21
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 22
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 23
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 24
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 25
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 26
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 27
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 28
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 29
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 30
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 31
# Neural Network Prediction: 7 (digit 7)
#
#
# Displaying Example Image 32
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 33
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 34
# Neural Network Prediction: 1 (digit 1)
#
#
# Displaying Example Image 35
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 36
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 37
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 38
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 39
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 40
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 41
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 42
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 43
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 44
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 45
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 46
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 47
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 48
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 49
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 50
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 51
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 52
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 53
# Neural Network Prediction: 1 (digit 1)
#
#
# Displaying Example Image 54
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 55
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 56
# Neural Network Prediction: 7 (digit 7)
#
#
# Displaying Example Image 57
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 58
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 59
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 60
# Neural Network Prediction: 7 (digit 7)
#
#
# Displaying Example Image 61
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 62
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 63
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 64
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 65
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 66
# Neural Network Prediction: 7 (digit 7)
#
#
# Displaying Example Image 67
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 68
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 69
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 70
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 71
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 72
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 73
# Neural Network Prediction: 7 (digit 7)
#
#
# Displaying Example Image 74
# Neural Network Prediction: 1 (digit 1)
#
#
# Displaying Example Image 75
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 76
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 77
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 78
# Neural Network Prediction: 1 (digit 1)
#
#
# Displaying Example Image 79
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 80
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 81
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 82
# Neural Network Prediction: 1 (digit 1)
#
#
# Displaying Example Image 83
# Neural Network Prediction: 9 (digit 9)
#
#
# Displaying Example Image 84
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 85
# Neural Network Prediction: 5 (digit 5)
#
#
# Displaying Example Image 86
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 87
# Neural Network Prediction: 3 (digit 3)
#
#
# Displaying Example Image 88
# Neural Network Prediction: 2 (digit 2)
#
#
# Displaying Example Image 89
# Neural Network Prediction: 8 (digit 8)
#
#
# Displaying Example Image 90
# Neural Network Prediction: 1 (digit 1)
#
#
# Displaying Example Image 91
# Neural Network Prediction: 1 (digit 1)
#
#
# Displaying Example Image 92
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 93
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 94
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 95
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 96
# Neural Network Prediction: 4 (digit 4)
#
#
# Displaying Example Image 97
# Neural Network Prediction: 10 (digit 0)
#
#
# Displaying Example Image 98
# Neural Network Prediction: 6 (digit 6)
#
#
# Displaying Example Image 99
# Neural Network Prediction: 9 (digit 9)
